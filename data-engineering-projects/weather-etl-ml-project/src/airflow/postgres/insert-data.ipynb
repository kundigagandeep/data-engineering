# %%
from sqlalchemy import create_engine
import sqlalchemy as sq 
import pandas as pd
conn = create_engine("postgresql://postgres:Speedy3861@localhost:5432/weather")

# %%
df = pd.read_csv('/Users/gagandeepkundi/data-engineering/projects/weather-etl-ml-project/src/airflow/dags/data/02_intermediate/weather.csv')

df = df.drop(columns='region').sort_values('last_updated')

df.tail()
# Out:
#        name country    lat   lon          tz_id  localtime_epoch  \
# 175  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670419802
# 176  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670420702
# 177  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670421602
# 178  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670422502
# 179  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670423402
#
#             localtime  last_updated_epoch      last_updated  temp_c  ...  \
# 175  2022-12-07 14:30          1670418900  2022-12-07 14:15     2.0  ...
# 176  2022-12-07 14:45          1670420700  2022-12-07 14:45     2.0  ...
# 177  2022-12-07 15:00          1670420700  2022-12-07 14:45     2.0  ...
# 178  2022-12-07 15:15          1670421600  2022-12-07 15:00     2.0  ...
# 179  2022-12-07 15:30          1670422500  2022-12-07 15:15     2.0  ...
#
#      precip_in  humidity cloud feelslike_c  feelslike_f  vis_km  vis_miles  \
# 175        0.0        93    75        -2.2         28.0    10.0        6.0
# 176        0.0        93    75        -2.2         28.0    10.0        6.0
# 177        0.0        93    75        -2.2         28.0    10.0        6.0
# 178        0.0        93    75        -2.5         27.4    10.0        6.0
# 179        0.0        93    75        -2.5         27.4    10.0        6.0
#
#       uv gust_mph  gust_kph
# 175  1.0     14.1      22.7
# 176  1.0     14.1      22.7
# 177  1.0     14.1      22.7
# 178  1.0     16.3      26.3
# 179  1.0     16.3      26.3
#
# [5 rows x 32 columns]

# %%
df = df.rename(columns={'localtime':'local_time',
                        'condition.text':'condition_text',
                        'condition.icon':'condition_icon',
                        'condition.code':'condition_code'})

# %%
df.to_sql('weather_warsaw', conn, if_exists="replace", index=False)
# Out:
# 180
