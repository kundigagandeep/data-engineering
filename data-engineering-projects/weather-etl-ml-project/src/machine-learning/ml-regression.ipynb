# %%
# evaluate prophet time series forecasting model on hold out dataset
import pandas as pd
from prophet import Prophet
from sklearn.metrics import mean_absolute_error
from matplotlib import pyplot

# %%
#load data
df = pd.read_csv('/Users/gagandeepkundi/data-engineering/projects/weather-etl-ml-project/src/airflow/dags/data/02_intermediate/weather.csv')

df = df.drop(columns='region').sort_values('last_updated')

df.tail()
# Out:
#       name country    lat   lon          tz_id  localtime_epoch  \
# 46  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670150703
# 47  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670151918
# 48  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670155124
# 49  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670155499
# 50  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670156102
#
#            localtime  last_updated_epoch      last_updated  temp_c  ...  \
# 46  2022-12-04 11:45          1670149800  2022-12-04 11:30     0.0  ...
# 47  2022-12-04 12:05          1670151600  2022-12-04 12:00     0.0  ...
# 48  2022-12-04 12:58          1670154300  2022-12-04 12:45     1.0  ...
# 49  2022-12-04 13:04          1670155200  2022-12-04 13:00     1.0  ...
# 50  2022-12-04 13:15          1670155200  2022-12-04 13:00     1.0  ...
#
#     precip_in  humidity cloud feelslike_c  feelslike_f  vis_km  vis_miles  \
# 46        0.0       100   100        -5.1         22.9     2.6        1.0
# 47        0.0       100   100        -5.2         22.7     2.7        1.0
# 48        0.0        93   100        -3.9         25.0     2.6        1.0
# 49        0.0        93   100        -4.0         24.8     2.6        1.0
# 50        0.0        93   100        -4.0         24.8     2.6        1.0
#
#      uv gust_mph  gust_kph
# 46  1.0     15.0      24.1
# 47  2.0     15.2      24.5
# 48  2.0     15.2      24.5
# 49  2.0     15.9      25.6
# 50  2.0     15.9      25.6
#
# [5 rows x 32 columns]
