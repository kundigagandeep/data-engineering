# %%
from sqlalchemy import create_engine
import sqlalchemy as sq 
import pandas as pd
conn = create_engine("postgresql://postgres:Speedy3861@localhost:5432/weather")

# %%
df = pd.read_csv('/Users/gagandeepkundi/data-engineering/projects/weather-etl-ml-project/src/airflow/dags/data/02_intermediate/weather.csv')

df = df.drop(columns='region').sort_values('last_updated')

df.tail()
# Out:
#        name country    lat   lon          tz_id  localtime_epoch  \
# 154  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670276650
# 155  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670279886
# 156  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670280183
# 157  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670281204
# 158  Warsaw  Poland  52.25  21.0  Europe/Warsaw       1670282105
#
#             localtime  last_updated_epoch      last_updated  temp_c  ...  \
# 154  2022-12-05 22:44          1670275800  2022-12-05 22:30     2.0  ...
# 155  2022-12-05 23:38          1670279400  2022-12-05 23:30     2.0  ...
# 156  2022-12-05 23:43          1670279400  2022-12-05 23:30     2.0  ...
# 157   2022-12-06 0:00          1670281200  2022-12-06 00:00     2.0  ...
# 158   2022-12-06 0:15          1670281200  2022-12-06 00:00     2.0  ...
#
#      precip_in  humidity cloud feelslike_c  feelslike_f  vis_km  vis_miles  \
# 154        0.0        87    75        -1.3         29.7    10.0        6.0
# 155        0.0        87    75        -0.9         30.3    10.0        6.0
# 156        0.0        87    75        -0.9         30.3    10.0        6.0
# 157        0.0        87    75        -0.9         30.5    10.0        6.0
# 158        0.0        87    75        -0.9         30.5    10.0        6.0
#
#       uv gust_mph  gust_kph
# 154  1.0     12.1      19.4
# 155  1.0     10.1      16.2
# 156  1.0     10.1      16.2
# 157  1.0     10.3      16.6
# 158  1.0     10.3      16.6
#
# [5 rows x 32 columns]

# %%
df = df.rename(columns={'localtime':'local_time',
                        'condition.text':'condition_text',
                        'condition.icon':'condition_icon',
                        'condition.code':'condition_code'})

# %%
df.to_sql('weather_warsaw', conn, if_exists="replace", index=False)
# Out:
# 159
